# %% [markdown]
# # Advanced Coding Final Project
#
# Written by Jiyun Tsai
# Data imported as of December 13th, 2022
# The latest data of citations are December 8th, 2022

# %% [markdown]
# ## Import Data

# %%
# Import data using pandas

import pandas as pd
import requests

# %%
# pip install sodapy

# %%
# Get API code instructions from (https://dev.socrata.com/foundry/data.sfgov.org/ab4h-6ztd)

# import pandas as pd
# from sodapy import Socrata


# client = Socrata("data.sfgov.org",
#                  "UBJcOCUaACnecZ7XJXpUT4tiG",
#                  username="jiyun_tsai@berkeley.edu",
#                  password="Password1022!")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
# results = client.get("ab4h-6ztd", limit="") ## how to get full data without limits?

# Convert to pandas DataFrame
# citation = pd.DataFrame.from_records(results)

# %%
# Read the file into Python
url = 'https://data.sfgov.org/api/views/ab4h-6ztd/rows.csv?accessType=DOWNLOAD'
r = requests.get(url, allow_redirects=False)

# Write the content of the request into a file called 'parking_citation.csv'
open('parking_citation.csv', 'wb').write(r.content)
# Out:
# 2799244853

# %%
# Import this .csv file to dataframe named "citation"
citation = pd.read_csv('parking_citation.csv')

# %%
citation
# Out:
#          Citation Number Citation Issued DateTime   Violation  \
# 0              771857995   10/27/2009 03:36:00 PM      T32A.1
# 1              771104246   09/14/2009 11:05:00 AM      V5204A
# 2              770561131   09/10/2009 03:30:00 PM        T202
# 3              770024076   09/07/2009 03:21:00 PM        T202
# 4              770025093   09/09/2009 01:23:00 PM        T58A
# ...                  ...                      ...         ...
# 19095155       955554246   11/03/2022 03:38:00 PM   TRC7.2.20
# 19095156       955110866   11/03/2022 12:00:00 PM   TRC7.2.29
# 19095157       956046582   11/03/2022 03:58:00 PM      V4000A
# 19095158       955906125   11/03/2022 10:07:00 AM  TRC7.2.23A
# 19095159       955833281   11/04/2022 11:51:00 AM  TRC7.2.23B
#
#          Violation Description          Citation Location Vehicle Plate State  \
# 0                   TWAWY ZN#1             669 MISSION ST                  CA
# 1                     REG TABS                 7 GROVE ST                  CA
# 2                    PRK METER               2851 24TH ST                  CA
# 3                    PRK METER                 417 BAY ST                  CA
# 4                   BLK WHEELS              136 LAWTON ST                  CA
# ...                        ...                        ...                 ...
# 19095155                RES/OT               3188 25TH ST                  CA
# 19095156            PK OVR 72H                569 24TH ST                  CA
# 19095157             NO EV REG             1451 GREAT HWY                  CA
# 19095158             METER DTN          109 SACRAMENTO ST                  CA
# 19095159            MTR OUT DT  719 TERRY A FRANCOIS BLVD                  CA
#
#          Vehicle Plate  Fine Amount              Date Added  \
# 0              6ANP484         83.0  10/27/2009 12:00:00 AM
# 1              5FEK647         63.0  09/14/2009 12:00:00 AM
# 2              6DEG966         53.0  09/10/2009 12:00:00 AM
# 3              6DKY758         53.0  09/07/2009 12:00:00 AM
# 4              4JTL645         48.0  09/09/2009 12:00:00 AM
# ...                ...          ...                     ...
# 19095155       7DEA930         99.0  12/09/2022 12:00:00 AM
# 19095156       4DA8056         76.0  12/11/2022 12:00:00 AM
# 19095157           NaN        209.0  12/11/2022 12:00:00 AM
# 19095158       96808L2         98.0  12/12/2022 12:00:00 AM
# 19095159       8XSC154         89.0  12/13/2022 12:00:00 AM
#
#                                                     geom  Neighborhoods  \
# 0          POINT (-122.40131583199997 37.78670342300006)           32.0
# 1          POINT (-122.41511664599994 37.77876024500006)           21.0
# 2         POINT (-122.40919778399996 37.752743407000025)           53.0
# 3          POINT (-122.41413599899994 37.80540600300003)          106.0
# 4          POINT (-122.46446999799997 37.75869600400006)          109.0
# ...                                                  ...            ...
# 19095155                                             NaN            NaN
# 19095156                                             NaN            NaN
# 19095157                                             NaN            NaN
# 19095158                                             NaN            NaN
# 19095159                                             NaN            NaN
#
#           SF Find Neighborhoods  Current Police Districts  \
# 0                          32.0                       1.0
# 1                          21.0                       5.0
# 2                          53.0                       3.0
# 3                         106.0                       6.0
# 4                         109.0                      10.0
# ...                         ...                       ...
# 19095155                    NaN                       NaN
# 19095156                    NaN                       NaN
# 19095157                    NaN                       NaN
# 19095158                    NaN                       NaN
# 19095159                    NaN                       NaN
#
#           Current Supervisor Districts  Analysis Neighborhoods
# 0                                 10.0                     8.0
# 1                                 10.0                    36.0
# 2                                  2.0                    20.0
# 3                                  3.0                    23.0
# 4                                  8.0                    14.0
# ...                                ...                     ...
# 19095155                           NaN                     NaN
# 19095156                           NaN                     NaN
# 19095157                           NaN                     NaN
# 19095158                           NaN                     NaN
# 19095159                           NaN                     NaN
#
# [19095160 rows x 15 columns]

# %%
citation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19095160 entries, 0 to 19095159
# Data columns (total 15 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Citation Number               object
#  1   Citation Issued DateTime      object
#  2   Violation                     object
#  3   Violation Description         object
#  4   Citation Location             object
#  5   Vehicle Plate State           object
#  6   Vehicle Plate                 object
#  7   Fine Amount                   float64
#  8   Date Added                    object
#  9   geom                          object
#  10  Neighborhoods                 float64
#  11  SF Find Neighborhoods         float64
#  12  Current Police Districts      float64
#  13  Current Supervisor Districts  float64
#  14  Analysis Neighborhoods        float64
# dtypes: float64(6), object(9)
# memory usage: 2.1+ GB

# %%
# See 'Violation' types
citation['Violation'].value_counts()
# Out:
# TRC7.2.22     4766121
# T37C          2397076
# TRC7.2.23B    1320822
# T202          1271179
# TRC7.2.20     1131156
#                ...
# GO1.H.4             1
# TC32.6.29           1
# H20.1               1
# BR2495.5C           1
# T32.6.7             1
# Name: Violation, Length: 305, dtype: int64

# %% [markdown]
# ## Street Cleaning Data in 5 Years (2018-2022)
# For street cleaning, the dataframe contains two codes in 'Violation' column: TRC7.2.22 and T37C, all data after 2018 use TRC7.2.22
# Filter dataframe before cleaning data for the whole dataframe is too large (19M rows of data)
#
# *code description and more info could be found [here](https://www.sfmta.com/sites/default/files/reports-and-documents/2022/10/fy_2023_fees_and_fines_effective_7.1.22_1.pdf)

# %% [markdown]
# ### Filter and Clean

# %%
# Filter data of street cleaning 'TRC7.2.22' 
citation_st_cleaning = citation[citation['Violation']== 'TRC7.2.22'].copy()

# %%
# Convert dtype for 'Citation Issued DateTime'
citation_st_cleaning['Citation Issued DateTime'] = pd.to_datetime(citation_st_cleaning['Citation Issued DateTime'])

# %%
# Filter data from 2018 to 2022 from citation_st_cleaning dataframe
citation_st_cleaning_5yr = citation_st_cleaning[citation_st_cleaning['Citation Issued DateTime'] >= '2018-01-01'].copy()

# %%
# Sort data by date and time
citation_st_cleaning_5yr.sort_values(by=['Citation Issued DateTime'])
# Out:
#          Citation Number Citation Issued DateTime  Violation  \
# 13815654       892597786      2018-01-02 00:03:00  TRC7.2.22
# 13823194       892536632      2018-01-02 00:08:00  TRC7.2.22
# 13858247       892597790      2018-01-02 00:08:00  TRC7.2.22
# 13832351       892597801      2018-01-02 00:09:00  TRC7.2.22
# 13608878       892257855      2018-01-02 00:10:00  TRC7.2.22
# ...                  ...                      ...        ...
# 18803863       957867805      2022-12-07 13:04:00  TRC7.2.22
# 18803306       957867820      2022-12-07 13:08:00  TRC7.2.22
# 18804607       957826796      2022-12-07 13:10:00  TRC7.2.22
# 18804574       957799846      2022-12-08 02:13:00  TRC7.2.22
# 18803885       957799872      2022-12-08 02:18:00  TRC7.2.22
#
#          Violation Description    Citation Location Vehicle Plate State  \
# 13815654             STR CLEAN            7 04TH ST                  CA
# 13823194             STR CLEAN          333 08TH ST                  CA
# 13858247             STR CLEAN        869 FOLSOM ST                  CA
# 13832351             STR CLEAN        839 FOLSOM ST                  CA
# 13608878             STR CLEAN      225 TOWNSEND ST                  CA
# ...                        ...                  ...                 ...
# 18803863             STR CLEAN     216 HOLLOWAY AVE                  CA
# 18803306             STR CLEAN  300 DE MONTFORT AVE                  CA
# 18804607             STR CLEAN        2507 16TH AVE                  MS
# 18804574             STR CLEAN        310 SUTTER ST                  CA
# 18803885             STR CLEAN         521 MASON ST                  CA
#
#          Vehicle Plate  Fine Amount              Date Added  \
# 13815654       8AGE461         73.0  10/15/2021 12:00:00 AM
# 13823194       7XSH956         73.0  09/24/2018 12:00:00 AM
# 13858247       6TZE100         73.0  04/30/2020 12:00:00 AM
# 13832351       7XBP248         73.0  06/16/2018 12:00:00 AM
# 13608878       6CWY869         73.0  04/12/2021 12:00:00 AM
# ...                ...          ...                     ...
# 18803863       C048435         87.0  12/13/2022 12:00:00 AM
# 18803306       C049726         87.0  12/13/2022 12:00:00 AM
# 18804607       KTB9442         87.0  12/13/2022 12:00:00 AM
# 18804574       8VKN378         87.0  12/13/2022 12:00:00 AM
# 18803885       7RCX715         87.0  12/13/2022 12:00:00 AM
#
#                                                     geom  Neighborhoods  \
# 13815654  POINT (-122.46585481399995 37.788244665000036)            4.0
# 13823194   POINT (-122.03654390799994 38.24835797800006)            NaN
# 13858247   POINT (-122.40263889499994 37.78079616600007)           32.0
# 13832351  POINT (-122.40196506399997 37.781329424000035)           32.0
# 13608878   POINT (-122.39345305299997 37.77822802800006)           34.0
# ...                                                  ...            ...
# 18803863                                             NaN            NaN
# 18803306                                             NaN            NaN
# 18804607                                             NaN            NaN
# 18804574                                             NaN            NaN
# 18803885                                             NaN            NaN
#
#           SF Find Neighborhoods  Current Police Districts  \
# 13815654                    4.0                       8.0
# 13823194                    NaN                       NaN
# 13858247                   32.0                       1.0
# 13832351                   32.0                       1.0
# 13608878                   34.0                       1.0
# ...                         ...                       ...
# 18803863                    NaN                       NaN
# 18803306                    NaN                       NaN
# 18804607                    NaN                       NaN
# 18804574                    NaN                       NaN
# 18803885                    NaN                       NaN
#
#           Current Supervisor Districts  Analysis Neighborhoods
# 13815654                           6.0                    11.0
# 13823194                           NaN                     NaN
# 13858247                          10.0                    34.0
# 13832351                          10.0                    34.0
# 13608878                          10.0                     4.0
# ...                                ...                     ...
# 18803863                           NaN                     NaN
# 18803306                           NaN                     NaN
# 18804607                           NaN                     NaN
# 18804574                           NaN                     NaN
# 18803885                           NaN                     NaN
#
# [2402440 rows x 15 columns]

# %%
# Check duplicates
citation_st_cleaning_5yr.nunique()
# Out:
# Citation Number                 2402440
# Citation Issued DateTime         626684
# Violation                             1
# Violation Description                 1
# Citation Location                602501
# Vehicle Plate State                 100
# Vehicle Plate                    978244
# Fine Amount                          13
# Date Added                         1262
# geom                             245357
# Neighborhoods                       117
# SF Find Neighborhoods               117
# Current Police Districts             10
# Current Supervisor Districts         11
# Analysis Neighborhoods               41
# dtype: int64

# %%
len(citation_st_cleaning_5yr) ## there are no duplicated rows for 'Citation Number'
# Out:
# 2402440

# %%
# Export filtered and cleaned dataframe as .csv for future analysis, data as of November 22, 2022
citation_st_cleaning_5yr.to_csv('citation_st_cleaning_5yr.csv', index=False)

# %% [markdown]
# Cleaned data (.csv file) can be accessed at [Google Drive](https://drive.google.com/drive/folders/1SJ0jPphZWaPy7h72a2X3uj4rI_nGH8hH?usp=share_link)
